# %%
import sys, os
import pandas as pd
import numpy as np
sys.version

# %%
# !ls /home/myao/dev/data/gamedata/data

# %%
# !ls .
# Out:
# gamedatav1.ipynb	process_join.py		 README.md
# practice.ipynb		process.py		 Untitled.ipynb
# process_deposit_his.py	process_take_columns.py

# %%
# !pwd
# Out:
# /home/myao/dev/git/gamedata

# %%
# !ls -l
# Out:
# total 476
# -rw-r--r-- 1 jovyan users 456548 Oct 17 19:48 gamedatav1.ipynb
# -rw-r--r-- 1 jovyan users   2343 Oct 11 17:07 practice.ipynb
# -rw-r--r-- 1 jovyan users   3010 Oct 11 18:38 process_deposit_his.py
# -rw-r--r-- 1 jovyan users   2070 Oct 10 19:59 process_join.py
# -rw-r--r-- 1 jovyan users   2596 Oct 10 18:48 process.py
# -rw-r--r-- 1 jovyan users   1858 Oct 17 18:26 process_take_columns.py
# -rw-r--r-- 1 jovyan users     10 Sep 27 21:37 README.md
# -rw-r--r-- 1 jovyan users    555 Oct 11 17:06 Untitled.ipynb

# %%
# !ls -l /home/myao/dev/data/gamedata/data
# Out:
# total 24829160
# -rw-r--r-- 1 jovyan users 1158842869 Oct  5 04:30 dn_character_his_3m.txt
# -rw-r--r-- 1 jovyan users 1145467974 Oct 10 18:05 dn_character_his_3m_utf-8.txt
# -rw-r--r-- 1 jovyan users  553063012 Oct 17 18:27 dn_character_his_map_uft-8.csv
# -rw-r--r-- 1 jovyan users 4900653952 Sep 28 08:10 dn_character_uft-8.csv
# -rw-r--r-- 1 jovyan users  154270506 Oct  5 04:30 dn_deposit_3m.txt
# -rw-r--r-- 1 jovyan users  152136841 Oct 10 18:48 dn_deposit_3m_utf-8.txt
# -rw-r--r-- 1 jovyan users  159452123 Oct 11 18:56 dn_deposit_char_map_3m_utf-8.txt
# -rw-r--r-- 1 jovyan users  159452123 Oct 11 07:42 dn_deposit_char_map_3m_utf-8.txt.bak
# -rw-r--r-- 1 jovyan users 2754367767 Sep 28 08:20 dn_friend_utf-8.txt
# -rw-r--r-- 1 jovyan users  614406592 Oct  1 02:47 dn_itemtrade_3m_union_utf-8.pkl.xz
# -rw-r--r-- 1 jovyan users 2316626257 Sep 28 08:33 dn_itemtrade_3m_union_utf-8.txt
# -rw-r--r-- 1 jovyan users 7984469644 Sep 28 07:56 dn_stage_end_log.txt
# ...

# %%
# !head -100 /home/myao/dev/data/gamedata/data/dn_itemtrade_3m_union_utf-8.txt
# Out:
# characterid_buyer,characterid_seller,AREA_ID,GROUP_ID,TRADEDATE,SELLER,BUYER,ITEMID,ITEMCOUNT,PRICE,REGISTERCOMMISSION,TRADECOMMISSION,DATA_DESC,ITEMSERIAL,ITEMLEVEL
# 10627119,21398670,1,,2011-02-24 13:01:19,kinglbj06,盛夏る庭院い,1107378176,1,990000,0,0,2011-02-24,676024207177426172,0
# 10627119,21453636,1,,2011-02-12 20:59:46,無言勿語,盛夏る庭院い,336605696,1,10050,0,0,2011-02-12,705005942199452236,0
# 10627119,21463587,1,,2011-02-13 22:24:33,李赢,盛夏る庭院い,872415266,11,10000,0,0,2011-02-13,705518877258532602,0
# 10627119,215804,1,,2011-03-25 15:53:57,gto、战神,盛夏る庭院い,277552128,1,1500635,0,0,2011-03-25,705609702935582188,0
# 10627119,21712859,1,,2011-01-28 20:53:13,moion,盛夏る庭院い,872415266,3,5000,0,0,2011-01-28,704102800769923905,0
# 10627119,21725898,1,,2011-02-14 21:39:28,寂寞———小太郎,盛夏る庭院い,306366480,1,12050,0,0,2011-02-14,676083224406466223,0
# 10627119,21883452,1,,2011-03-26 20:25:56,qk鱼雷,盛夏る庭院い,336617984,20,7500,0,0,2011-03-26,705820139153377461,0
# ...
